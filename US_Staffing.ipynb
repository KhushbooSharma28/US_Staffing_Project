# %%
import pandas as pd

# %%
df = pd.read_excel(r"C:\Users\Khushboo Sharma\Desktop\US Staffing Project\US_IT_Staffing_Analytics_Dataset.xlsx") #read data

# %%
df #Look at the date
# Out:
#    Candidate ID    Candidate Name    Prime Vendor          End Client  \
# 0      CAND1000      Elijah Davis      TEKsystems      JPMorgan Chase
# 1      CAND1001  William Williams      TEKsystems                AT&T
# 2      CAND1002        Noah Moore        Randstad                AT&T
# 3      CAND1003      Daniel Moore  Insight Global               Apple
# 4      CAND1004    Lucas Anderson        NTT DATA               Apple
# ..          ...               ...             ...                 ...
# 95     CAND1095    Elijah Johnson    Apex Systems               Apple
# 96     CAND1096         Mia Brown          Kforce               Cisco
# 97     CAND1097       Emma Taylor         Experis               Apple
# 98     CAND1098      Olivia Moore      TEKsystems              Amazon
# 99     CAND1099  Isabella Johnson    Apex Systems  UnitedHealth Group
#
#            BDM Name Recruiter      Job Category Job Type (C2C/W2/1099)  \
# ...

# %%
df.head() # looking top 5 rows from data
# Out:
#   Candidate ID    Candidate Name    Prime Vendor      End Client     BDM Name  \
# 0     CAND1000      Elijah Davis      TEKsystems  JPMorgan Chase  Ankit Verma
# 1     CAND1001  William Williams      TEKsystems            AT&T  Rahul Mehta
# 2     CAND1002        Noah Moore        Randstad            AT&T  Neha Kapoor
# 3     CAND1003      Daniel Moore  Insight Global           Apple  Priya Singh
# 4     CAND1004    Lucas Anderson        NTT DATA           Apple  Priya Singh
#
#   Recruiter      Job Category Job Type (C2C/W2/1099)  Bill Rate  Pay Rate  \
# 0     Karan      Data Analyst                    C2C         91        67
# 1     Karan   DevOps Engineer                   1099         94        64
# 2     Vikas    Java Developer                    C2C        106        63
# 3    Ritika  Business Analyst                   1099        118        66
# 4     Karan      Data Analyst                   1099        103        78
#
# ...

# %%
df.tail()  #late 5 rows
# Out:
#    Candidate ID    Candidate Name  Prime Vendor          End Client  \
# 95     CAND1095    Elijah Johnson  Apex Systems               Apple
# 96     CAND1096         Mia Brown        Kforce               Cisco
# 97     CAND1097       Emma Taylor       Experis               Apple
# 98     CAND1098      Olivia Moore    TEKsystems              Amazon
# 99     CAND1099  Isabella Johnson  Apex Systems  UnitedHealth Group
#
#            BDM Name Recruiter      Job Category Job Type (C2C/W2/1099)  \
# 95      Neha Kapoor     Karan   DevOps Engineer                   1099
# 96      Ankit Verma     Pooja  Python Developer                   1099
# 97      Ankit Verma    Deepak  Business Analyst                   1099
# 98  Khushboo Sharma     Rohit     Data Engineer                   1099
# 99      Ankit Verma     Rohit    Java Developer                     W2
#
#     Bill Rate  Pay Rate  Margin Submission Date Interview Date  Offer Date  \
# ...

# %%
df.describe() # Summary statistics
# Out:
#         Bill Rate    Pay Rate      Margin
# count  100.000000  100.000000  100.000000
# mean    95.920000   66.760000   29.160000
# std     14.665758   15.339999   14.514166
# min     70.000000   45.000000   10.000000
# 25%     83.000000   56.750000   17.750000
# 50%     95.500000   63.000000   25.000000
# 75%    110.000000   78.000000   39.000000
# max    120.000000  102.000000   70.000000

# %%
df.shape # total num of rows and col
# Out:
# (100, 16)

# %%
df.isnull().sum() #check the null values
# Out:
# Candidate ID              0
# Candidate Name            0
# Prime Vendor              0
# End Client                0
# BDM Name                  0
# Recruiter                 0
# Job Category              0
# Job Type (C2C/W2/1099)    0
# Bill Rate                 0
# Pay Rate                  0
# Margin                    0
# Submission Date           0
# Interview Date            0
# Offer Date                0
# Joining Date              0
# Candidate Status          0
# dtype: int64

# %%
# Handle missing values

df["Interview Date"] = df["Interview Date"] = fillna("No Interview")

# %%
df["Offer Date"] = df["Offer Date"].fillna("Coming Soon")

# %%
df["Joining Date"] = df["Joining Date"].fillna("pending")

# %%
df.isnull().sum()
# Out:
# Candidate ID              0
# Candidate Name            0
# Prime Vendor              0
# End Client                0
# BDM Name                  0
# Recruiter                 0
# Job Category              0
# Job Type (C2C/W2/1099)    0
# Bill Rate                 0
# Pay Rate                  0
# Margin                    0
# Submission Date           0
# Interview Date            0
# Offer Date                0
# Joining Date              0
# Candidate Status          0
# dtype: int64

# %%
df.duplicated().sum() #checking any duplicate values
# Out:
# np.int64(0)

# %%
#Clean column names

df.columns
# Out:
# Index(['CandidateID', 'CandidateName', 'PrimeVendor', 'EndClient', 'BDMName',
#        'Recruiter', 'JobCategory', 'JobType', 'BillRate', 'PayRate', 'Margin',
#        'SubmissionDate', 'InterviewDate', 'OfferDate', 'JoiningDate',
#        'CandidateStatus'],
#       dtype='object')

# %%
df.columns = df.columns.str.strip()

# %%
df.columns
# Out:
# Index(['CandidateID', 'CandidateName', 'PrimeVendor', 'EndClient', 'BDMName',
#        'Recruiter', 'JobCategory', 'JobType', 'BillRate', 'PayRate', 'Margin',
#        'SubmissionDate', 'InterviewDate', 'OfferDate', 'JoiningDate',
#        'CandidateStatus'],
#       dtype='object')

# %%
df.columns = df.columns.str.replace("_","")

# %%
df.columns
# Out:
# Index(['CandidateID', 'CandidateName', 'PrimeVendor', 'EndClient', 'BDMName',
#        'Recruiter', 'JobCategory', 'JobType(C2C/W2/1099)', 'BillRate',
#        'PayRate', 'Margin', 'SubmissionDate', 'InterviewDate', 'OfferDate',
#        'JoiningDate', 'CandidateStatus'],
#       dtype='object')

# %%
df.columns = df.columns.str.replace("JobType(C2C/W2/1099)","Job_Type")

# %%
df.columns
# Out:
# Index(['CandidateID', 'CandidateName', 'PrimeVendor', 'EndClient', 'BDMName',
#        'Recruiter', 'JobCategory', 'JobType', 'BillRate', 'PayRate', 'Margin',
#        'SubmissionDate', 'InterviewDate', 'OfferDate', 'JoiningDate',
#        'CandidateStatus'],
#       dtype='object')

# %%
df.columns
# Out:
# Index(['CandidateID', 'CandidateName', 'PrimeVendor', 'EndClient', 'BDMName',
#        'Recruiter', 'JobCategory', 'JobType', 'BillRate', 'PayRate', 'Margin',
#        'SubmissionDate', 'InterviewDate', 'OfferDate', 'JoiningDate',
#        'CandidateStatus'],
#       dtype='object')

# %%
df.columns = df.columns.str.lower()
df.columns
# Out:
# Index(['candidateid', 'candidatename', 'primevendor', 'endclient', 'bdmname',
#        'recruiter', 'jobcategory', 'jobtype', 'billrate', 'payrate', 'margin',
#        'submissiondate', 'interviewdate', 'offerdate', 'joiningdate',
#        'candidatestatus'],
#       dtype='object')

# %%
df.columns
# Out:
# Index(['candidateid', 'candidatename', 'primevendor', 'endclient', 'bdmname',
#        'recruiter', 'jobcategory', 'jobtype', 'billrate', 'payrate', 'margin',
#        'submissiondate', 'interviewdate', 'offerdate', 'joiningdate',
#        'candidatestatus'],
#       dtype='object')

# %%
df.columns = [
    "candidate_id",
    "candidate_name",
    "prime_vendor",
    "end_client",
    "bdm_name",
    "recruiter",
    "job_category",
    "job_type",
    "bill_rate",
    "pay_rate",
    "margin",
    "submission_date",
    "interview_date",
    "offer_date",
    "joining_date",
    "candidate_status"
]

# %%
df.columns
# Out:
# Index(['candidate_id', 'candidate_name', 'prime_vendor', 'end_client',
#        'bdm_name', 'recruiter', 'job_category', 'job_type', 'bill_rate',
#        'pay_rate', 'margin', 'submission_date', 'interview_date', 'offer_date',
#        'joining_date', 'candidate_status'],
#       dtype='object')

# %%
df.info() #df.dtypes both will show the datatypes
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 16 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   candidate_id      100 non-null    object
#  1   candidate_name    100 non-null    object
#  2   prime_vendor      100 non-null    object
#  3   end_client        100 non-null    object
#  4   bdm_name          100 non-null    object
#  5   recruiter         100 non-null    object
#  6   job_category      100 non-null    object
#  7   job_type          100 non-null    object
#  8   bill_rate         100 non-null    int64
#  9   pay_rate          100 non-null    int64
#  10  margin            100 non-null    int64
#  11  submission_date   100 non-null    object
#  12  interview_date    100 non-null    object
#  13  offer_date        100 non-null    object
#  14  joining_date      100 non-null    object
#  15  candidate_status  100 non-null    object
# dtypes: int64(3), object(13)
# ...

# %%
df.dtypes  #object means text
# Out:
# candidate_id        object
# candidate_name      object
# prime_vendor        object
# end_client          object
# bdm_name            object
# recruiter           object
# job_category        object
# job_type            object
# bill_rate            int64
# pay_rate             int64
# margin               int64
# submission_date     object
# interview_date      object
# offer_date          object
# joining_date        object
# candidate_status    object
# dtype: object

# %%
df["submission_date"] = pd.to_datetime(df["submission_date"])

# %%
df.dtypes
# Out:
# candidate_id                object
# candidate_name              object
# prime_vendor                object
# end_client                  object
# bdm_name                    object
# recruiter                   object
# job_category                object
# job_type                    object
# bill_rate                    int64
# pay_rate                     int64
# margin                       int64
# submission_date     datetime64[ns]
# interview_date              object
# offer_date                  object
# joining_date                object
# candidate_status            object
# dtype: object

# %%
df["bill_rate"] = df["bill_rate"].astype(float)

# %%
df["pay_rate"] = df["pay_rate"].astype(float)

# %%
df["margin"] = df["margin"].astype(float)

# %%
df.dtypes
# Out:
# candidate_id                object
# candidate_name              object
# prime_vendor                object
# end_client                  object
# bdm_name                    object
# recruiter                   object
# job_category                object
# job_type                    object
# bill_rate                  float64
# pay_rate                   float64
# margin                     float64
# submission_date     datetime64[ns]
# interview_date              object
# offer_date                  object
# joining_date                object
# candidate_status            object
# dtype: object

# %%
df["candidate_status"].unique()  #checking the unique values
# Out:
# array(['Offer Released', 'Joined', 'Rejected', 'Submitted',
#        'Interview Scheduled', 'Offer Declined'], dtype=object)

# %%
df["candidate_status"] = df["candidate_status"].str.title()

# %%
df.info("candidate_status")
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 16 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   candidate_id      100 non-null    object
#  1   candidate_name    100 non-null    object
#  2   prime_vendor      100 non-null    object
#  3   end_client        100 non-null    object
#  4   bdm_name          100 non-null    object
#  5   recruiter         100 non-null    object
#  6   job_category      100 non-null    object
#  7   job_type          100 non-null    object
#  8   bill_rate         100 non-null    float64
#  9   pay_rate          100 non-null    float64
#  10  margin            100 non-null    float64
#  11  submission_date   100 non-null    datetime64[ns]
#  12  interview_date    100 non-null    object
#  13  offer_date        100 non-null    object
#  14  joining_date      100 non-null    object
#  15  candidate_status  100 non-null    object
# ...

# %%
#Check Date Logic - it means I am checking that candidates joining date is later than the interview date 


df[df["joining_date"] < df["interview_date"]]
# Out:
# Empty DataFrame
# Columns: [candidate_id, candidate_name, prime_vendor, end_client, bdm_name, recruiter, job_category, job_type, bill_rate, pay_rate, margin, submission_date, interview_date, offer_date, joining_date, candidate_status]
# Index: []

# %%
#checking outliners in bill rate, pay rate and margin

df["bill_rate"].describe()
# Out:
# count    100.000000
# mean      95.920000
# std       14.665758
# min       70.000000
# 25%       83.000000
# 50%       95.500000
# 75%      110.000000
# max      120.000000
# Name: bill_rate, dtype: float64

# %%
df["pay_rate"].describe()
# Out:
# count    100.000000
# mean      66.760000
# std       15.339999
# min       45.000000
# 25%       56.750000
# 50%       63.000000
# 75%       78.000000
# max      102.000000
# Name: pay_rate, dtype: float64

# %%
df["margin"].describe()
# Out:
# count    100.000000
# mean      29.160000
# std       14.514166
# min       10.000000
# 25%       17.750000
# 50%       25.000000
# 75%       39.000000
# max       70.000000
# Name: margin, dtype: float64

# %%
df[df["pay_rate"] > df["bill_rate"]]
# Out:
# Empty DataFrame
# Columns: [candidate_id, candidate_name, prime_vendor, end_client, bdm_name, recruiter, job_category, job_type, bill_rate, pay_rate, margin, submission_date, interview_date, offer_date, joining_date, candidate_status]
# Index: []

# %%
df[df["bill_rate"] < 0]
# Out:
# Empty DataFrame
# Columns: [candidate_id, candidate_name, prime_vendor, end_client, bdm_name, recruiter, job_category, job_type, bill_rate, pay_rate, margin, submission_date, interview_date, offer_date, joining_date, candidate_status]
# Index: []

# %%
df[df["pay_rate"] < 0]
# Out:
# Empty DataFrame
# Columns: [candidate_id, candidate_name, prime_vendor, end_client, bdm_name, recruiter, job_category, job_type, bill_rate, pay_rate, margin, submission_date, interview_date, offer_date, joining_date, candidate_status]
# Index: []

# %%
df[df["margin"] < 0]
# Out:
# Empty DataFrame
# Columns: [candidate_id, candidate_name, prime_vendor, end_client, bdm_name, recruiter, job_category, job_type, bill_rate, pay_rate, margin, submission_date, interview_date, offer_date, joining_date, candidate_status]
# Index: []

# %%
#Pandas does NOT automatically save your changes to the Excel file.
#saving the cleaned dataset coz the changes are made only in memory (inside Python session).

df.to_excel(
    r"C:\Users\Khushboo Sharma\Desktop\US Staffing Project\US_IT_Staffing_Cleaned.xlsx",
    index=False)

# %%
df= pd.read_excel(r"C:\Users\Khushboo Sharma\Desktop\US Staffing Project\US_IT_Staffing_Cleaned.xlsx")

# %%
df.head()
# Out:
#   candidate_id    candidate_name    prime_vendor      end_client     bdm_name  \
# 0     CAND1000      Elijah Davis      TEKsystems  JPMorgan Chase  Ankit Verma
# 1     CAND1001  William Williams      TEKsystems            AT&T  Rahul Mehta
# 2     CAND1002        Noah Moore        Randstad            AT&T  Neha Kapoor
# 3     CAND1003      Daniel Moore  Insight Global           Apple  Priya Singh
# 4     CAND1004    Lucas Anderson        NTT DATA           Apple  Priya Singh
#
#   recruiter      job_category job_type  bill_rate  pay_rate  margin  \
# 0     Karan      Data Analyst      C2C         91        67      24
# 1     Karan   DevOps Engineer     1099         94        64      30
# 2     Vikas    Java Developer      C2C        106        63      43
# 3    Ritika  Business Analyst     1099        118        66      52
# 4     Karan      Data Analyst     1099        103        78      25
#
#   submission_date interview_date   offer_date joining_date candidate_status
# ...

# %%
#Connecting with SQL 

# !pip install SQLALchemy pymysql

# %%
from sqlalchemy import create_engine 

connection = create_engine("mysql+pymysql://root:7321@localhost/us_staffing")

# %%
df.to_sql(
    name = "staffing_data", #we are creating a table(not already in mysql)
    con = connection,   #using the connection - this will connect to the database(already in sql)
    if_exists="replace",    # Replace table if it already exists
    index=False             # Don't create an extra index column
)
print("Data successfully uploaded to MySQL!")
# Out:
# Data successfully uploaded to MySQL!
